# %% [markdown]
# # CRAR

# %%
import math
import torch
import torch.nn as nn
from torch.optim import Adam
import gym
from utils import ReplayBuffer
import random
import numpy as np
import utils as u

# %%
from IPython.display import clear_output
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
USE_CUDA = torch.cuda.is_available()
device = 'cuda' if USE_CUDA else 'cpu'
device = torch.device(device)

# %%
def plot(frame_idx, rewards, losses):
    clear_output(True)
    plt.figure(figsize=(20,5))
    plt.subplot(131)
    plt.title('frame %s. reward: %s' % (frame_idx, np.mean(rewards[-10:])))
    plt.plot(rewards)
    plt.subplot(132)
    plt.title('loss')
    plt.plot(losses)
    plt.show()

# %% [markdown]
# ## CartPole

# %%
env_id = "CartPole-v0"
env = gym.make(env_id)

# %%
ABSTRACT_STATE_DIM = np.array([3])

# %%
from model import SimpleQNetwork, SimpleEncoder, RewardPredictor

encoder = SimpleEncoder(env.observation_space.shape, device, ABSTRACT_STATE_DIM[0]).to(device)
reward_predictor = RewardPredictor(ABSTRACT_STATE_DIM[0]).to(device)
current_model = SimpleQNetwork(ABSTRACT_STATE_DIM, env.action_space.n, device).to(device)
target_model = SimpleQNetwork(ABSTRACT_STATE_DIM, env.action_space.n, device).to(device)

encoder_optimizer = Adam(encoder.parameters())
reward_pred_optimizer = Adam(reward_predictor.parameters())
optimizer = Adam(current_model.parameters())
u.synchronize_target_model(current_model, target_model)

replay_buffer = ReplayBuffer(5000)

# %%
epsilon_start = 1.0
epsilon_final = 0.01
epsilon_decay = 1000

epsilon_by_frame = lambda frame_idx: epsilon_final + (epsilon_start - epsilon_final) * math.exp(-1. * frame_idx / epsilon_decay)

# %%
plt.plot([epsilon_by_frame(i) for i in range(10000)])

# %%
from loss import q_td_loss_optim, double_q_td_loss_optim, crar_loss_optim 
# compute_td_loss = q_td_loss_optim
# compute_td_loss = double_q_td_loss_optim
compute_td_loss = crar_loss_optim

# %%
import wandb

# %%
# WandB – Initialize a new run
wandb.init(entity="aayn", project="crar-first-qd")
wandb.watch_called = False # Re-run the model without restarting the runtime, unnecessary after our next release

# WandB – Config is a variable that holds and saves hyperparameters and inputs
config = wandb.config          # Initialize config
config.batch_size = 64          # input batch size for training (default: 64)
config.test_batch_size = 64    # input batch size for testing (default: 1000)
config.seed = 42               # random seed (default: 42)
config.log_interval = 200     # how many batches to wait before logging training status
# Out:
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/aayn/crar-first-qd" target="_blank">https://app.wandb.ai/aayn/crar-first-qd</a><br/>
#                 Run page: <a href="https://app.wandb.ai/aayn/crar-first-qd/runs/1psqsrrp" target="_blank">https://app.wandb.ai/aayn/crar-first-qd/runs/1psqsrrp</a><br/>

# %%
wandb.watch(current_model, log="all")
wandb.watch(encoder, log="all")

# %%
num_frames = 4000
batch_size = 64
gamma      = 0.99

losses = []
all_dq_losses, all_reward_losses, all_repr_losses = [], [], []
all_rewards = []
episode_reward = 0

state = env.reset()

for frame_idx in range(1, num_frames + 1):
    epsilon = epsilon_by_frame(frame_idx)
    action = current_model.act(encoder(state), epsilon)
    
    next_state, reward, done, _ = env.step(action)
    replay_buffer.push(state, action, reward, next_state, done)
    
    state = next_state
    episode_reward += reward
    
    if done:
        state = env.reset()
        wandb.log({'Episode Return': episode_reward})
        all_rewards.append(episode_reward)
        episode_reward = 0
        
    if len(replay_buffer) > batch_size:
        dq_loss, reward_loss, repr_loss, loss = compute_td_loss(batch_size, gamma, encoder, reward_predictor, current_model, target_model, optimizer, encoder_optimizer, reward_pred_optimizer, replay_buffer, device)
        losses.append(loss.item())
    
        all_dq_losses.append(dq_loss)
        all_reward_losses.append(reward_loss)
        all_repr_losses.append(repr_loss)
        
        if frame_idx % 10 == 0:
            
            wandb.log({'Double-Q Loss': dq_loss})
            wandb.log({'Representation Loss': repr_loss})
            wandb.log({'Reward Prediction Loss': reward_loss})
            wandb.log({'Loss': loss})
            # wandb.log({'Reward': reward})
            plot(frame_idx, all_rewards, losses)
            if frame_idx % 400 == 0:
                u.synchronize_target_model(current_model, target_model)

# %% [markdown]
# ## Pong

# %%
from wrappers import make_atari, wrap_deepmind, wrap_pytorch

# %%
env_id = "PongNoFrameskip-v4"
env    = make_atari(env_id)
env    = wrap_deepmind(env)
env    = wrap_pytorch(env)

# %%
ABSTRACT_STATE_DIM = np.array([5])

# %%
from model import SimpleQNetwork, Encoder, RewardPredictor

encoder = Encoder(env.observation_space.shape, device, ABSTRACT_STATE_DIM[0]).to(device)
reward_predictor = RewardPredictor(ABSTRACT_STATE_DIM[0]).to(device)
current_model = SimpleQNetwork(ABSTRACT_STATE_DIM, env.action_space.n, device).to(device)
target_model = SimpleQNetwork(ABSTRACT_STATE_DIM, env.action_space.n, device).to(device)

encoder_optimizer = Adam(encoder.parameters())
reward_pred_optimizer = Adam(reward_predictor.parameters())
optimizer = Adam(current_model.parameters())
u.synchronize_target_model(current_model, target_model)

replay_initial = 10000
replay_buffer = ReplayBuffer(100000)

# %%
epsilon_start = 1.0
epsilon_final = 0.01
epsilon_decay = 100000

epsilon_by_frame = lambda frame_idx: epsilon_final + (epsilon_start - epsilon_final) * math.exp(-1. * frame_idx / epsilon_decay)

# %%
from loss import crar_loss_optim
compute_td_loss = crar_loss_optim

# %%
num_frames = 1400000
batch_size = 32
gamma      = 0.99

losses = []
all_rewards = []
episode_reward = 0

state = env.reset()
for frame_idx in range(1, num_frames + 1):
    epsilon = epsilon_by_frame(frame_idx)
    action = current_model.act(encoder(np.expand_dims(state, 0)), epsilon)
    
    next_state, reward, done, _ = env.step(action)
    replay_buffer.push(state, action, reward, next_state, done)
    
    state = next_state
    episode_reward += reward
    
    if done:
        state = env.reset()
        all_rewards.append(episode_reward)
        episode_reward = 0
        
    if len(replay_buffer) > replay_initial:
        loss = compute_td_loss(
            batch_size, gamma, encoder, reward_predictor, 
            current_model, target_model, optimizer, encoder_optimizer,
            reward_pred_optimizer, replay_buffer, device
        )
        losses.append(loss[-1].item())
        
    if frame_idx % 500 == 0:
        plot(frame_idx, all_rewards, losses)
        if frame_idx % 1000 == 0:
            u.synchronize_target_model(current_model, target_model)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-8de2c9289200> in <module>
#      27             batch_size, gamma, encoder, reward_predictor,
#      28             current_model, target_model, optimizer, encoder_optimizer,
# ---> 29             reward_pred_optimizer, replay_buffer, device
#      30         )
#      31         losses.append(loss[-1].item())
#
# ~/Programming/yarl/algorithms/crar/loss.py in crar_loss_optim(batch_size, gamma, encoder, reward_predictor, current_model, target_model, optimizer, encoder_optimizer, reward_pred_optimizer, replay_buffer, device)
#     125     loss.backward()
#     126     optimizer.step()
# --> 127     encoder_optimizer.step()
#     128     reward_pred_optimizer.step()
#     129
#
# ~/miniconda3/envs/spinningup/lib/python3.6/site-packages/torch/optim/adam.py in step(self, closure)
#      93
#      94                 # Decay the first and second moment running average coefficient
# ---> 95                 exp_avg.mul_(beta1).add_(1 - beta1, grad)
#      96                 exp_avg_sq.mul_(beta2).addcmul_(1 - beta2, grad, grad)
#      97                 if amsgrad:
#
# KeyboardInterrupt:

# %%
torch.save(model.state_dict(), 'saved_weights/qnetwork.pt')

# %%
model.load_state_dict(torch.load('saved_weights/qnetwork.pt'))
# Out:
# <All keys matched successfully>
